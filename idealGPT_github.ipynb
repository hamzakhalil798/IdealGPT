# %% [markdown]
# #clonning Repo

# %%
# !git clone https://github.com/Hxyou/IdealGPT.git
# conda env create -f environment.yml
# conda activate idealgpt
# Out:
# Cloning into 'IdealGPT'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 69 (delta 28), reused 44 (delta 12), pack-reused 0
# Receiving objects: 100% (69/69), 160.75 KiB | 2.11 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/drive/MyDrive/IdealGPT

# %%
cd /content/IdealGPT
# Out:
# /content/drive/MyDrive/IdealGPT

# %% [markdown]
# #Installing reqs

# %%
# !pip install openai==0.28
# !pip install salesforce-lavis==1.0.2
# !pip install shortuuid
# !pip install transformers -U
# !pip install jsonlines
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 39.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 28.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 12.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Downloading Dataset
#
# It's better to download dataset in drive and then extract in colab or extract in drive as well. As Dataset is huge and will cause issue of space in colab.

# %%
# !mkdir vcr1
# %cd vcr1
# !wget https://s3.us-west-2.amazonaws.com/ai2-rowanz/vcr1annots.zip
# !wget https://s3.us-west-2.amazonaws.com/ai2-rowanz/vcr1images.zip
# !unzip /content/drive/MyDrive/IdealGPT/vcr1/vcr1annots.zip
# !unzip /content/drive/MyDrive/IdealGPT/vcr1/vcr1images.zip
# !rm vcr1annots.zip
# !rm vcr1images.zip
# %cd ../
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: vcr1images/movieclips_Cool_as_Ice/0yOwWkbamyM@7.json
#   inflating: vcr1images/movieclips_Cool_as_Ice/0yOwWkbamyM@26.json
#   inflating: vcr1images/movieclips_Cool_as_Ice/0yOwWkbamyM@17.json
#   inflating: vcr1images/movieclips_Cool_as_Ice/zJ5Nxx3H-Tc@7.json
#   inflating: vcr1images/movieclips_Cool_as_Ice/MqMD1DK0CTQ@0.jpg
#   inflating: vcr1images/movieclips_Cool_as_Ice/0yOwWkbamyM@70.json
#   inflating: vcr1images/movieclips_Cool_as_Ice/0yOwWkbamyM@26.jpg
#   inflating: vcr1images/movieclips_Cool_as_Ice/b8oFKKPfgi0@7.jpg
#   inflating: vcr1images/movieclips_Cool_as_Ice/zJ5Nxx3H-Tc@27.jpg
#   inflating: vcr1images/movieclips_Cool_as_Ice/y7gfbVpraWw@8.json
#   inflating: vcr1images/movieclips_Cool_as_Ice/_ElAIqSBTKc@12.jpg
#   inflating: vcr1images/movieclips_Cool_as_Ice/zJ5Nxx3H-Tc@27.json
#   inflating: vcr1images/movieclips_Cool_as_Ice/zJ5Nxx3H-Tc@7.jpg
# ...

# %%
cd /content/drive/MyDrive/IdealGPT
# Out:
# /content/drive/MyDrive/IdealGPT

# %% [markdown]
# #Sampling data

# %%
# %cd misc
# !python sample_data.py --dataset=vcr_val
# %cd ..
# Out:
# /content/drive/MyDrive/IdealGPT/misc
# 26534it [00:01, 21992.56it/s]
# Finish Sampling vcr_val; Obtained 1 samples.
# Finish writing to /content/vcr1/exp_data/vcr_val_random1_annoid.yaml
# /content/drive/MyDrive/IdealGPT

# %% [markdown]
# #Inference

# %%
# !python blip_gpt_main.py  \
    --data_root=/content/vcr1 \
    --exp_tag=vcr_05241522 \
    --dataset=vcr_val \
    --device_id='0' \
    --prompt_setting=v1a \
    --data_partition=0_499 \
    --vqa_model=blip2_opt_2.7b  \
    --temp_gpt=0.0  \
    --data_subset=/content/vcr1/exp_data/vcr_val_random1_annoid.yaml \
    --openai_key='enter your key here'
# Out:
# 26534it [00:00, 39121.91it/s]
# Finish loading data
# Start loading VQA model
# 2024-05-16 11:39:59.716839: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-16 11:39:59.716924: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-16 11:39:59.725458: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-16 11:40:02.004226: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading checkpoint shards: 100% 2/2 [01:18<00:00, 39.29s/it]
# Finish loading VQA model blip2_opt_2.7b
# ...
